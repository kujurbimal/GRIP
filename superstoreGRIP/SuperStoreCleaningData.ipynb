# %%
import pandas as pd

# %%
df_clean = pd.read_csv('SampleSuperstore.csv', index_col='Postal Code')

# %%
df_clean
# Out:
#                   Ship Mode    Segment        Country             City  \
# Postal Code
# 42420          Second Class   Consumer  United States        Henderson
# 42420          Second Class   Consumer  United States        Henderson
# 90036          Second Class  Corporate  United States      Los Angeles
# 33311        Standard Class   Consumer  United States  Fort Lauderdale
# 33311        Standard Class   Consumer  United States  Fort Lauderdale
# ...                     ...        ...            ...              ...
# 33180          Second Class   Consumer  United States            Miami
# 92627        Standard Class   Consumer  United States       Costa Mesa
# 92627        Standard Class   Consumer  United States       Costa Mesa
# 92627        Standard Class   Consumer  United States       Costa Mesa
# 92683          Second Class   Consumer  United States      Westminster
#
#                   State Region         Category Sub-Category     Sales  \
# Postal Code
# ...

# %%
df_clean.shape
# Out:
# (9994, 12)

# %%
pd.set_option('display.max_columns', 21)
pd.set_option('display.max_rows', 5)

# %%
df_clean.columns = ['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9994 entries, 42420 to 92683
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Region        9994 non-null   object
#  6   Category      9994 non-null   object
#  7   Sub-Category  9994 non-null   object
#  8   Sales         9994 non-null   float64
#  9   Quantity      9994 non-null   int64
#  10  Discount      9994 non-null   float64
#  11  Profit        9994 non-null   float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 1015.0+ KB
